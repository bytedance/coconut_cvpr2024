# %% [markdown]
# Set up environments

# %%
from panopticapi.utils import rgb2id

from detectron2.utils.visualizer import ColorMode, Visualizer
from detectron2.data import MetadataCatalog

from PIL import Image
from coco_meta import COCO_META

import matplotlib.pyplot as plt
import numpy as np

# %%
# load image
image =  Image.open('demo_image.jpg')

# load panoptic mask
panoptic_orig = np.asarray(Image.open('demo_mask.png'), dtype=np.uint32)
panoptic_seg = rgb2id(panoptic_orig).astype(np.int32)

# show image
image.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426>

# %%
# set up detectron2 visualizer
# create a visualizer using COCO meta
instance_mode=ColorMode.IMAGE
metadata=MetadataCatalog.get(
            "coco_2017_val_panoptic" 
        )
visualizer = Visualizer(image, metadata, instance_mode=instance_mode)

# %%
import json
# load demo segments_info pre-extracted from relabeled_coco_val.json
with open('demo_segments_info.json','r') as f:
    segments_info=json.load(f)
    
print(segments_info)
# Out:
# [{'id': 1, 'category_id': 118, 'iscrowd': 0, 'isthing': 0, 'area': 45822}, {'id': 2, 'category_id': 200, 'iscrowd': 0, 'isthing': 0, 'area': 13049}, {'id': 3, 'category_id': 199, 'iscrowd': 0, 'isthing': 0, 'area': 71688}, {'id': 4, 'category_id': 186, 'iscrowd': 0, 'isthing': 0, 'area': 26476}, {'id': 5, 'category_id': 189, 'iscrowd': 0, 'isthing': 0, 'area': 10083}, {'id': 6, 'category_id': 188, 'iscrowd': 0, 'isthing': 0, 'area': 24448}, {'id': 7, 'category_id': 181, 'iscrowd': 0, 'isthing': 0, 'area': 11474}, {'id': 8, 'category_id': 180, 'iscrowd': 0, 'isthing': 0, 'area': 4166}, {'id': 9, 'category_id': 156, 'iscrowd': 0, 'isthing': 0, 'area': 5767}, {'id': 10, 'category_id': 130, 'iscrowd': 0, 'isthing': 0, 'area': 3314}, {'id': 11, 'category_id': 119, 'iscrowd': 0, 'isthing': 0, 'area': 1103}, {'id': 12, 'category_id': 72, 'isthing': 1, 'area': 13718, 'iscrowd': 0}, {'id': 13, 'category_id': 62, 'isthing': 1, 'area': 2113, 'iscrowd': 0}, {'id': 14, 'category_id': 62, 'isthing': 1, 'area': 1258, 'iscrowd': 0}, {'id': 15, 'category_id': 1, 'isthing': 1, 'area': 487, 'iscrowd': 0}, {'id': 16, 'category_id': 78, 'isthing': 1, 'area': 243, 'iscrowd': 0}, {'id': 17, 'category_id': 82, 'isthing': 1, 'area': 2298, 'iscrowd': 0}, {'id': 18, 'category_id': 85, 'isthing': 1, 'area': 226, 'iscrowd': 0}, {'id': 19, 'category_id': 86, 'isthing': 1, 'area': 2208, 'iscrowd': 0}, {'id': 20, 'category_id': 86, 'isthing': 1, 'area': 182, 'iscrowd': 0}, {'id': 21, 'category_id': 86, 'isthing': 1, 'area': 150, 'iscrowd': 0}, {'id': 22, 'category_id': 86, 'isthing': 1, 'area': 94, 'iscrowd': 0}, {'id': 23, 'category_id': 62, 'isthing': 1, 'area': 188, 'iscrowd': 0}, {'id': 24, 'category_id': 62, 'isthing': 1, 'area': 252, 'iscrowd': 0}, {'id': 25, 'category_id': 62, 'isthing': 1, 'area': 2098, 'iscrowd': 0}, {'id': 26, 'category_id': 62, 'isthing': 1, 'area': 736, 'iscrowd': 0}, {'id': 27, 'category_id': 1, 'isthing': 1, 'area': 3031, 'iscrowd': 0}, {'id': 28, 'category_id': 67, 'isthing': 1, 'area': 2903, 'iscrowd': 0}, {'id': 29, 'category_id': 86, 'isthing': 1, 'area': 558, 'iscrowd': 0}]

# %%
# create category ids to continuous ids mapper from COCO_META 
catid2cont_id={}
for i,meta in enumerate(COCO_META[1:]):
    catid2cont_id[meta['id']]=i
    
    
# convert category ids to continuous category ids using the defined mapper
# need to split the segments_info from the annotation json file first by filtering the image_id
for segment in segments_info:
    # replace with the new continus id
    segment['category_id']=catid2cont_id[segment['category_id']]

# %%
import torch
vis_output = visualizer.draw_panoptic_seg_predictions(
        torch.from_numpy(panoptic_seg), segments_info
    )

# %%
# save the visualization
vis_output.save('./vis_panseg_demo.png')

# show the visualization
vis_output_img=vis_output.get_image()
plt.imshow(vis_output_img)
plt.axis('off')
plt.show()
